# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("thyroid_cancer_risk_data.csv")

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender  Country  Ethnicity Family_History  \
# 0           1   66    Male   Russia  Caucasian             No
# 1           2   29    Male  Germany   Hispanic             No
# 2           3   86    Male  Nigeria  Caucasian             No
# 3           4   75  Female    India      Asian             No
# 4           5   35  Female  Germany    African            Yes
#
#   Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  TSH_Level  \
# 0                Yes                No      No      No       No       9.37
# 1                Yes                No      No      No       No       1.83
# 2                 No                No      No      No       No       6.26
# 3                 No                No      No      No       No       4.10
# 4                Yes                No      No      No       No       9.10
#
#    T3_Level  T4_Level  Nodule_Size Thyroid_Cancer_Risk Diagnosis
# 0      1.67      6.16         1.08                 Low    Benign
# 1      1.73     10.54         4.05                 Low    Benign
# 2      2.59     10.57         4.61                 Low    Benign
# 3      2.62     11.04         2.46              Medium    Benign
# 4      2.11     10.71         2.11                High    Benign

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Country', 'Ethnicity', 'Family_History',
#        'Radiation_Exposure', 'Iodine_Deficiency', 'Smoking', 'Obesity',
#        'Diabetes', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size',
#        'Thyroid_Cancer_Risk', 'Diagnosis'],
#       dtype='object')

# %%
colms = [
    'Patient_ID', 'Age', 'Gender', 'Country', 'Ethnicity', 'Family_History',
       'Radiation_Exposure', 'Iodine_Deficiency', 'Smoking', 'Obesity',
       'Diabetes', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size',
       'Thyroid_Cancer_Risk', 'Diagnosis'
]
for unique_values in colms:
    print(f"{unique_values:30}: {df[unique_values].unique()}\n")
# Out:
# Patient_ID                    : [     1      2      3 ... 212689 212690 212691]
#
# Age                           : [66 29 86 75 35 89 38 17 36 67 16 44 52 78 74 47 72 63 73 56 76 61 65 69
#  21 87 53 32 18 28 23 85 58 22 49 50 64 20 68 77 48 88 62 54 40 55 43 59
#  79 15 25 19 42 26 37 51 41 57 27 46 80 71 84 70 33 82 31 83 30 34 81 45
#  39 60 24]
#
# Gender                        : ['Male' 'Female']
#
# Country                       : ['Russia' 'Germany' 'Nigeria' 'India' 'UK' 'South Korea' 'Brazil' 'China'
#  'Japan' 'USA']
#
# Ethnicity                     : ['Caucasian' 'Hispanic' 'Asian' 'African' 'Middle Eastern']
#
# Family_History                : ['No' 'Yes']
#
# Radiation_Exposure            : ['Yes' 'No']
#
# Iodine_Deficiency             : ['No' 'Yes']
#
# Smoking                       : ['No' 'Yes']
#
# Obesity                       : ['No' 'Yes']
#
# Diabetes                      : ['No' 'Yes']
#
# TSH_Level                     : [ 9.37  1.83  6.26  4.1   9.1   4.    4.7   5.54  2.3   1.34  9.65  0.53
#   6.77  4.91  6.84  7.32  9.6   3.59  6.43  5.96  4.17  6.97  3.18  0.14
#   6.02  7.9   0.87  4.99  4.07  4.42  7.29  6.27  3.35  1.64  3.16  3.98
#   5.85  8.74  6.65  6.38  5.86  4.57  7.58  6.49  2.85  2.9   0.94  8.99
#  4.89 1.27 0.22 2.81 1.93 2.07 2.21 1.99 3.67 2.53 1.21 4.02 1.45 0.45
#  4.4  4.14 0.52 4.97 4.92 0.49 4.46 1.97 2.36 1.31 0.76 0.16 1.71 2.51
#  0.31 2.42 4.44 4.31 2.15 3.73 3.52 0.79 3.03 4.8  2.87 0.64 4.28 4.36
#  2.43 0.61 3.85 0.32 4.68 2.17 4.59 0.58 3.82 1.42 2.66 3.2  3.23 1.46
#  2.9  2.95 4.5  2.45 2.98 3.48 1.43 3.44 4.16 1.18 1.13 4.66 1.04 3.42
#  0.93 2.09 3.75 1.84 3.45 2.97 2.91 1.81 2.12 3.43 3.7  0.94 3.   2.08
#  0.9  0.14 4.98 0.56 3.27 2.29 1.48 4.07 2.24 3.28 4.51 4.91 3.68 4.72
#  0.6  1.87 4.76 1.61 1.55 1.89 0.12 3.13 0.96 3.58 4.48 0.11 3.74 0.85
#  2.76 1.53 0.74 1.83 2.89 4.37 4.2  2.3  3.89 2.93 3.71 0.08 4.57 3.46
#  0.21 1.03 4.84 4.56 3.79 3.18 2.74 1.77 4.34 2.57 0.43 4.73 4.17 1.2
#  4.18 2.16 0.54 3.78 1.65 3.12 0.89 3.49 1.8  0.63 2.92 4.24 1.62 3.92
#  3.21 4.75 2.96 3.07 2.1  3.66 1.58 0.67 3.77 2.35 1.72 3.1  0.99 3.98
#  0.1  0.53 3.88 0.62 4.09 0.8  0.51 3.96 4.1  1.26 2.56 3.02 3.38 1.74
#  0.75 3.34 0.5  1.12 3.11 1.6  3.72 0.88 1.94 4.82 1.9  0.34 1.78 1.35
#  4.74 4.33 2.63 3.26 1.   3.04 1.4  1.85 0.69 1.56 4.9  4.13 2.64 1.32
#  0.7  0.   3.22 2.31 0.87 2.73 1.5  1.92 1.88 0.36 3.62 1.67 2.99 0.28
#  4.03 3.35 4.32 3.37 2.06 4.41 5.   3.99 2.84 0.57 0.41 1.52 2.38 2.49
#  4.43 1.24 3.47 1.98 4.45 1.34 1.96 2.13 4.95 4.52 2.47 4.69 3.05 0.55
#  4.53 4.58 3.39 4.38 2.28 2.65 3.84 0.78 1.49 0.4  2.25 4.29 2.79 1.73
#  3.6  2.39 1.01 4.6  1.29 1.51 4.42 2.62 1.69 2.2  4.86]
#
# Thyroid_Cancer_Risk           : ['Low' 'Medium' 'High']
#
# Diagnosis                     : ['Benign' 'Malignant']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212691 entries, 0 to 212690
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Gender               212691 non-null  object
#  1   Country              212691 non-null  object
#  2   Ethnicity            212691 non-null  object
#  3   Family_History       212691 non-null  object
#  4   Radiation_Exposure   212691 non-null  object
#  5   Iodine_Deficiency    212691 non-null  object
#  6   Smoking              212691 non-null  object
#  7   Obesity              212691 non-null  object
#  8   Diabetes             212691 non-null  object
#  9   TSH_Level            212691 non-null  float64
#  10  T3_Level             212691 non-null  float64
#  11  T4_Level             212691 non-null  float64
#  12  Nodule_Size          212691 non-null  float64
#  13  Thyroid_Cancer_Risk  212691 non-null  object
#  14  Diagnosis            212691 non-null  object
# dtypes: float64(4), object(11)
# memory usage: 24.3+ MB

# %%
df.drop(columns='Patient_ID', inplace=True)
df[df['Nodule_Size']==0][['Nodule_Size','Diagnosis']]
# Out:
#         Nodule_Size  Diagnosis
# 1075            0.0  Malignant
# 1415            0.0  Malignant
# 3271            0.0     Benign
# 3437            0.0     Benign
# 4893            0.0     Benign
# ...             ...        ...
# 211223          0.0     Benign
# 211367          0.0     Benign
# 211439          0.0     Benign
# 211830          0.0     Benign
# 212510          0.0     Benign
#
# [196 rows x 2 columns]

# %%
df[df['Nodule_Size'] == 0.0]['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Benign       151
# Malignant     45
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#            TSH_Level       T3_Level       T4_Level    Nodule_Size
# count  212691.000000  212691.000000  212691.000000  212691.000000
# mean        5.045102       2.001727       8.246204       2.503403
# std         2.860264       0.866248       2.164188       1.444631
# min         0.100000       0.500000       4.500000       0.000000
# 25%         2.570000       1.250000       6.370000       1.250000
# 50%         5.040000       2.000000       8.240000       2.510000
# 75%         7.520000       2.750000      10.120000       3.760000
# max        10.000000       3.500000      12.000000       5.000000

# %%
zero_nodule_stats = df[df['Nodule_Size'] == 0.0][['TSH_Level', 'T3_Level', 'T4_Level']].describe()
print(zero_nodule_stats)
# Out:
#         TSH_Level   T3_Level    T4_Level
# count  196.000000  196.00000  196.000000
# mean     4.774643    1.96602    8.093673
# std      2.968510    0.85339    2.185528
# min      0.300000    0.52000    4.620000
# 25%      2.227500    1.20000    6.092500
# 50%      4.415000    1.95500    7.745000
# 75%      7.175000    2.78250   10.072500
# max      9.970000    3.48000   11.990000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 4))  # shorter height
sns.set_style("whitegrid")

bins = [0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5]

sns.histplot(df['Nodule_Size'],
             bins=bins,
             kde=True,
             color="#9998DD",  
             edgecolor="#520C52",
             shrink=0.8)

plt.title('Nodule_Size Distribution', fontsize=16, fontweight='bold', color='pink')
plt.xlabel('Nodule_Size', fontweight='bold', color='yellow')
plt.xticks(bins, fontweight='bold', color='black')
plt.yticks(fontweight='bold', color='green')
plt.ylabel('Frequency', fontweight='bold', color='white')

plt.legend(['KDE Curve'])
sns.despine()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Style
sns.set_style("whitegrid")
plt.figure(figsize=(8, 5))

# Gender counts
gender_counts = df['Gender'].value_counts()

# Bar plot
bars = plt.bar(
    gender_counts.index,
    gender_counts.values,
    color=sns.color_palette("coolwarm", len(gender_counts)),
    edgecolor='black'
)

# Add labels
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 500,
             f'{int(bar.get_height())}', ha='center', fontsize=11,
             fontweight='bold', color="#333333")

# Titles & labels
plt.title('Distribution of Gender', fontsize=16, fontweight='bold', color='#084C61')
plt.xlabel('Gender', fontsize=13, fontweight='bold', color='#084C61')
plt.ylabel('Count', fontsize=13, fontweight='bold', color='#084C61')

# Clean look
sns.despine()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

counts = df['Family_History'].value_counts()

# Custom colors (choose any hex codes or named colors)
custom_colors = ['#FF6F61', '#6BAED6', '#41B883'][:len(counts)]

bars = plt.bar(counts.index, counts.values, color=custom_colors, edgecolor='black')

# Add labels on top
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 500, 
             f'{int(bar.get_height())}', ha='center', fontsize=10, fontweight='bold')

# Titles and labels
plt.title('Family History', fontsize=15, fontweight='bold', color='#084C61')
plt.xlabel('Family History', fontweight='bold', color='#084C61')
plt.ylabel('Count', fontweight='bold', color='#084C61')

sns.despine()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Percentage counts
counts = df['Thyroid_Cancer_Risk'].value_counts(normalize=True) * 100

plt.figure(figsize=(7, 4))
sns.set_style("whitegrid")

# Simple palette (you can try "Set2", "pastel", "muted", etc.)
sns.barplot(x=counts.index, y=counts.values, palette="Set2")

# Titles & labels
plt.title('Thyroid Cancer Risk Distribution (%)', fontsize=14, fontweight='bold', color='navy')
plt.xlabel('Risk Level', fontsize=12, fontweight='bold', color='navy')
plt.ylabel('Percentage', fontsize=12, fontweight='bold', color='navy')
plt.ylim(0, 100)

# Add values on top
for i, val in enumerate(counts.values):
    plt.text(i, val + 1, f'{val:.1f}%', ha='center', fontsize=10, fontweight='bold', color='black')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\NAGESH\AppData\Local\Temp\ipykernel_9156\3939771807.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette="Set2")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 5))
sns.set_style("whitegrid")

# Different color for each country
ax = sns.countplot(
    data=df,
    x='Country',
    palette="Set3"   # or try "tab20", "Paired", "Dark2"
)

# Titles & labels
plt.title("Country vs Thyroid Cancer Risk", fontsize=14, fontweight='bold', color="#104150")
plt.xlabel('Country', fontweight='bold', color="#104150")
plt.ylabel("Count", fontweight='bold', color="#104150")
plt.xticks(rotation=45, fontweight='bold', color="#104150")
plt.yticks(fontweight='bold', color="#104150")

# Add count labels on bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height() + 200,
            f'{int(p.get_height())}', ha='center', fontsize=9, fontweight='bold', color='black')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\NAGESH\AppData\Local\Temp\ipykernel_9156\120830548.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
plt.figure(figsize=(12, 5))
palette = sns.color_palette("tab10")
ax=sns.countplot(data=df, x='Ethnicity', hue='Thyroid_Cancer_Risk', palette=palette)
plt.title("Ethnicity vs Thyroid Cancer Risk", fontsize=14, fontweight='bold')
plt.xlabel('Ethnicity')
plt.ylabel("Count")
plt.legend(title='Risk Level')
for p in ax.patches:
    height = p.get_height()
    ax.text(
        p.get_x() + p.get_width() / 2,   # X-position (center of bar)
        height + 500,                    # Y-position (just above the bar)
        f'{int(height)}',                # Text (count value)
        ha='center', va='bottom', 
        fontsize=10, fontweight='bold', color='black'
    )
plt.tight_layout()
plt.show()
# Out:
# C:\Users\NAGESH\AppData\Local\Temp\ipykernel_9156\1290726731.py:3: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   ax=sns.countplot(data=df, x='Ethnicity', hue='Thyroid_Cancer_Risk', palette=palette)

# %%
plt.figure(figsize=(8, 5))
palette = sns.color_palette("muted")
ax=sns.countplot(data=df, x='Family_History', hue='Thyroid_Cancer_Risk', palette=palette)
plt.title("Family_History vs Thyroid Cancer Risk", fontsize=14, fontweight='bold')
plt.xlabel('Family_History')
plt.ylabel("Count")
plt.legend(title='Risk Level')
# Add counts on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(
        p.get_x() + p.get_width() / 2,  
        height + 500,                    
        f'{int(height)}',                
        ha='center', va='bottom', 
        fontsize=10, fontweight='bold', color='black'
    )
plt.tight_layout()
plt.show()
# Out:
# C:\Users\NAGESH\AppData\Local\Temp\ipykernel_9156\1834982655.py:3: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   ax=sns.countplot(data=df, x='Family_History', hue='Thyroid_Cancer_Risk', palette=palette)
